# %% [markdown]
# # Name: Onabamiro Moyosore Faith

# %% [markdown]
# # Matric Number: 23/0550

# %% [markdown]
# # 1. DATA TYPES AND EXAMPLES

# %%
integer_example = 1005 
float_example = 3.14 
complex_example = 1+2j
string_example = "Hello, Axel" 
boolean_example = True

# %%
print("Integer",integer_example)
print("Float",float_example)
print("Complex",complex_example)
print("String",string_example)
print("Boolean",boolean_example)
# Out:
# Integer 1005
# Float 3.14
# Complex (1+2j)
# String Hello, Axel
# Boolean True

# %% [markdown]
# # 2. DATA STRUCTURES AND EXAMPLES

# %%
list_example = [10,20,30,40]
tuple_example = (1,2,3,4)
set_example = {5,10,15,20}
dictionary_example = {"name:","Moyo:","age :","21"}

# %%
print("List",list_example)
print("Tuple",tuple_example)
print("Test",set_example)
print("Dictionary",dictionary_example)
# Out:
# List [10, 20, 30, 40]
# Tuple (1, 2, 3, 4)
# Test {10, 20, 5, 15}
# Dictionary {'Moyo:', 'age :', 'name:', '21'}
